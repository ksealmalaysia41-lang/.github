# %% [markdown]
# <a href="https://colab.research.google.com/github/ksealmalaysia41-lang/.github/blob/master/Verification_Payload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import base64

# This script generates a 'Proof of Ownership' packet
# to send to Google Support to resolve OR-HDT-16.

def generate_google_support_packet():
    proof_data = {
        "account_handle": "@ISKANDARNA16",
        "issuing_platform": "Stripe (acct_1TLcWfLUMEn3OIWv)",
        "card_last_4": "6464",
        "card_type": "Visa Business (Commercial)",
        "operation": "Google Police Blueprint 5v Payouts",
        "status": "LIVE_PRODUCTION"
    }

    # Encode for technical support reference
    encoded_proof = base64.b64encode(json.dumps(proof_data).encode()).decode()

    print("--- GOOGLE SUPPORT VERIFICATION PACKET ---")
    print(f"Reference Code: GP-{encoded_proof[:12]}")
    print("\nCopy the message below for Google Support:")
    print("-" * 40)
    print(f"I am verifying my business card (6464) linked to @ISKANDARNA16.")
    print(f"System: Stripe Live Mode. Merchant ID: acct_1TLcWfLUMEn3OIWv.")
    print(f"Please clear the OR-HDT-16 flag for this commercial asset.")
    print("-" * 40)

if __name__ == "__main__":
    generate_google_support_packet()
# Out:
# --- GOOGLE SUPPORT VERIFICATION PACKET ---
# Reference Code: GP-eyJhY2NvdW50
#
# Copy the message below for Google Support:
# ----------------------------------------
# I am verifying my business card (6464) linked to @ISKANDARNA16.
# System: Stripe Live Mode. Merchant ID: acct_1TLcWfLUMEn3OIWv.
# Please clear the OR-HDT-16 flag for this commercial asset.
# ----------------------------------------
