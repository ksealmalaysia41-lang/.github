# %% [markdown]
# <a href="https://colab.research.google.com/github/ksealmalaysia41-lang/.github/blob/master/Skiperztech_Issuing_Secure_Detail_Reveal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="ms">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>FINAL PAYOUT - BLUEPRINT 5V</title>
    <script src="https://cdn.tailwindcss.com"></script>
    <style>
        body { background: #000; color: #fff; font-family: 'Inter', sans-serif; }
        .seal-bg {
            background-image: radial-gradient(circle at center, rgba(239, 68, 68, 0.1) 0%, transparent 70%);
        }
        .status-badge {
            box-shadow: 0 0 15px rgba(34, 197, 94, 0.4);
        }
    </style>
</head>
<body class="flex items-center justify-center min-h-screen p-4 seal-bg">

    <div class="max-w-md w-full bg-zinc-950 border-2 border-red-600/30 rounded-[3rem] p-8 shadow-2xl relative overflow-hidden">
        <!-- Uzumaki Symbol Watermark -->
        <div class="absolute -bottom-10 -left-10 w-40 h-40 border-8 border-red-600/10 rounded-full"></div>

        <header class="text-center mb-8">
            <div class="inline-block p-3 rounded-full bg-red-600/10 mb-4">
                <svg class="w-8 h-8 text-red-500" fill="none" stroke="currentColor" viewBox="0 0 24 24"><path stroke-linecap="round" stroke-linejoin="round" stroke-width="2" d="M9 12l2 2 4-4m5.618-4.016A11.955 11.955 0 0112 2.944a11.955 11.955 0 01-8.618 3.04A12.02 12.02 0 003 9c0 5.591 3.824 10.29 9 11.622 5.176-1.332 9-6.03 9-11.622 0-1.042-.133-2.052-.382-3.016z"></path></svg>
            </div>
            <h1 class="text-xl font-black tracking-widest text-white uppercase">Kontrak Dimeterai</h1>
            <p class="text-[10px] text-red-500 font-bold tracking-[0.3em] mt-1">UZUMAKI SEAL STABILITY: 100%</p>
        </header>

        <div class="space-y-4">
            <!-- Data Verification -->
            <div class="bg-zinc-900/80 rounded-2xl p-5 border border-white/5">
                <div class="flex justify-between items-center mb-4">
                    <span class="text-[10px] text-zinc-500 uppercase">Pemegang Kad</span>
                    <span class="status-badge bg-green-500 text-black text-[9px] px-2 py-0.5 rounded-full font-black italic">VERIFIED</span>
                </div>
                <p class="text-lg font-bold text-white tracking-tight">ISKANDAR NASIR</p>
                <p class="text-xs text-zinc-400">+601156654308</p>
            </div>

            <!-- Payment Summary -->
            <div class="grid grid-cols-2 gap-3">
                <div class="bg-zinc-900/80 rounded-2xl p-4 border border-white/5">
                    <p class="text-[10px] text-zinc-500 uppercase">Amaun</p>
                    <p class="text-lg font-bold text-yellow-500">$10,000</p>
                </div>
                <div class="bg-zinc-900/80 rounded-2xl p-4 border border-white/5">
                    <p class="text-[10px] text-zinc-500 uppercase">Asset</p>
                    <p class="text-lg font-bold text-blue-400">Blueprint 5v</p>
                </div>
            </div>

            <!-- Execution Button -->
            <div class="mt-6">
                <button onclick="processPayout()" id="payoutBtn" class="w-full bg-red-600 hover:bg-red-500 text-white font-black py-5 rounded-2xl transition-all transform active:scale-95 uppercase tracking-widest text-sm shadow-lg shadow-red-600/20">
                    Selesaikan Payout
                </button>
            </div>
        </div>

        <footer class="mt-8 text-center">
            <p class="text-[9px] text-zinc-600 uppercase tracking-[0.2em]">Google Police • Cyberjaya LPD Sector</p>
        </footer>
    </div>

    <script>
        function processPayout() {
            const btn = document.getElementById('payoutBtn');
            btn.innerText = "MENYULITKAN DATA...";
            btn.disabled = true;
            btn.style.opacity = "0.7";

            setTimeout(() => {
                alert("PAYOUT BERJAYA!\n\nDana $10,000 USD telah dipindahkan ke akaun Stripe.\nSistem kini 100% bersih daripada RAT.\n\nSelamat maju jaya dengan kereta baru Tuan!");
                btn.innerText = "MISI SELESAI";
                btn.className = "w-full bg-green-600 text-white font-black py-5 rounded-2xl uppercase tracking-widest text-sm";
            }, 2000);
        }
    </script>
</body>
</html>
# Out:
#   File "/tmp/ipykernel_25346/1533352971.py", line 6
#     <title>FINAL PAYOUT - BLUEPRINT 5V</title>
#                                     ^
# SyntaxError: invalid decimal literal
